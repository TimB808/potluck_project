# %% [markdown]
# # Imports

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /home/tim/.pyenv/versions/3.10.6/envs/potluck_project/lib/python3.10/site-packages (3.8.1)
# Requirement already satisfied: joblib in /home/tim/.pyenv/versions/3.10.6/envs/potluck_project/lib/python3.10/site-packages (from nltk) (1.2.0)
# Requirement already satisfied: click in /home/tim/.pyenv/versions/3.10.6/envs/potluck_project/lib/python3.10/site-packages (from nltk) (8.1.3)
# Requirement already satisfied: tqdm in /home/tim/.pyenv/versions/3.10.6/envs/potluck_project/lib/python3.10/site-packages (from nltk) (4.65.0)
# Requirement already satisfied: regex>=2021.8.3 in /home/tim/.pyenv/versions/3.10.6/envs/potluck_project/lib/python3.10/site-packages (from nltk) (2022.10.31)

# %%
import pandas as pd 

######################### WORDS

import string 
from nltk import word_tokenize

import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')

from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /home/tim/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/tim/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/tim/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/tim/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %% [markdown]
# # Import Data

# %%
alex_file1 = "/home/alexl/code/TimB808/potluck_project/raw_data/RAW_recipes.csv"
tim_file1 = "/home/tim/code/TimB808/potluck_project/raw_data/RAW_recipes.csv"

# update variable depending on user
df = pd.read_csv(tim_file1)

df.head(2)
# Out:
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
#
#    contributor_id   submitted  \
# 0           47892  2005-09-16
# 1           26278  2002-06-17
#
#                                                 tags  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...
# 1  ['30-minutes-or-less', 'time-to-make', 'course...
#
#                                    nutrition  n_steps  \
# 0      [51.5, 0.0, 13.0, 0.0, 2.0, 0.0, 4.0]       11
# 1  [173.4, 18.0, 0.0, 17.0, 22.0, 35.0, 1.0]        9
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
#
#                                          description  \
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...
#
#                                          ingredients  n_ingredients
# 0  ['winter squash', 'mexican seasoning', 'mixed ...              7
# 1  ['prepared pizza crust', 'sausage patty', 'egg...              6

# %%
df.columns
# Out:
# Index(['name', 'id', 'minutes', 'contributor_id', 'submitted', 'tags',
#        'nutrition', 'n_steps', 'steps', 'description', 'ingredients',
#        'n_ingredients'],
#       dtype='object')

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Dropping columns

# %%
new_df_shorter = df.iloc[:50]
new_df_shorter.head()
# Out:
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                   all in the kitchen  chili  112140      130
# 3                          alouette  potatoes   59389       45
# 4          amish  tomato ketchup  for canning   44061      190
#
#    contributor_id   submitted  \
# 0           47892  2005-09-16
# 1           26278  2002-06-17
# 2          196586  2005-02-25
# 3           68585  2003-04-14
# 4           41706  2002-10-25
#
#                                                 tags  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...
# 1  ['30-minutes-or-less', 'time-to-make', 'course...
# 2  ['time-to-make', 'course', 'preparation', 'mai...
# 3  ['60-minutes-or-less', 'time-to-make', 'course...
# 4  ['weeknight', 'time-to-make', 'course', 'main-...
#
#                                     nutrition  n_steps  \
# 0       [51.5, 0.0, 13.0, 0.0, 2.0, 0.0, 4.0]       11
# 1   [173.4, 18.0, 0.0, 17.0, 22.0, 35.0, 1.0]        9
# 2  [269.8, 22.0, 32.0, 48.0, 39.0, 27.0, 5.0]        6
# 3   [368.1, 17.0, 10.0, 2.0, 14.0, 8.0, 20.0]       11
# 4   [352.9, 1.0, 337.0, 23.0, 3.0, 0.0, 28.0]        5
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['brown ground beef in large pot', 'add choppe...
# 3  ['place potatoes in a large pot of lightly sal...
# 4  ['mix all ingredients& boil for 2 1 / 2 hours ...
#
#                                          description  \
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...
# 2  this modified version of 'mom's' chili was a h...
# 3  this is a super easy, great tasting, make ahea...
# 4  my dh's amish mother raised him on this recipe...
#
#                                          ingredients  n_ingredients
# 0  ['winter squash', 'mexican seasoning', 'mixed ...              7
# 1  ['prepared pizza crust', 'sausage patty', 'egg...              6
# 2  ['ground beef', 'yellow onions', 'diced tomato...             13
# 3  ['spreadable cheese with garlic and herbs', 'n...             11
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...              8

# %%
new_df_droppedcols = new_df_shorter.drop(columns=['id', 'minutes', 'contributor_id', 'submitted', 'tags',
       'nutrition', 'n_steps', 'description', 'n_ingredients'])

# %%
new_df_droppedcols.head()
# Out:
#                                          name  \
# 0  arriba   baked winter squash mexican style
# 1            a bit different  breakfast pizza
# 2                   all in the kitchen  chili
# 3                          alouette  potatoes
# 4          amish  tomato ketchup  for canning
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['brown ground beef in large pot', 'add choppe...
# 3  ['place potatoes in a large pot of lightly sal...
# 4  ['mix all ingredients& boil for 2 1 / 2 hours ...
#
#                                          ingredients
# 0  ['winter squash', 'mexican seasoning', 'mixed ...
# 1  ['prepared pizza crust', 'sausage patty', 'egg...
# 2  ['ground beef', 'yellow onions', 'diced tomato...
# 3  ['spreadable cheese with garlic and herbs', 'n...
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...

# %%
new_df_shorter.head()
# Out:
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                   all in the kitchen  chili  112140      130
# 3                          alouette  potatoes   59389       45
# 4          amish  tomato ketchup  for canning   44061      190
#
#    contributor_id   submitted  \
# 0           47892  2005-09-16
# 1           26278  2002-06-17
# 2          196586  2005-02-25
# 3           68585  2003-04-14
# 4           41706  2002-10-25
#
#                                                 tags  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...
# 1  ['30-minutes-or-less', 'time-to-make', 'course...
# 2  ['time-to-make', 'course', 'preparation', 'mai...
# 3  ['60-minutes-or-less', 'time-to-make', 'course...
# 4  ['weeknight', 'time-to-make', 'course', 'main-...
#
#                                     nutrition  n_steps  \
# 0       [51.5, 0.0, 13.0, 0.0, 2.0, 0.0, 4.0]       11
# 1   [173.4, 18.0, 0.0, 17.0, 22.0, 35.0, 1.0]        9
# 2  [269.8, 22.0, 32.0, 48.0, 39.0, 27.0, 5.0]        6
# 3   [368.1, 17.0, 10.0, 2.0, 14.0, 8.0, 20.0]       11
# 4   [352.9, 1.0, 337.0, 23.0, 3.0, 0.0, 28.0]        5
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['brown ground beef in large pot', 'add choppe...
# 3  ['place potatoes in a large pot of lightly sal...
# 4  ['mix all ingredients& boil for 2 1 / 2 hours ...
#
#                                          description  \
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...
# 2  this modified version of 'mom's' chili was a h...
# 3  this is a super easy, great tasting, make ahea...
# 4  my dh's amish mother raised him on this recipe...
#
#                                          ingredients  n_ingredients
# 0  ['winter squash', 'mexican seasoning', 'mixed ...              7
# 1  ['prepared pizza crust', 'sausage patty', 'egg...              6
# 2  ['ground beef', 'yellow onions', 'diced tomato...             13
# 3  ['spreadable cheese with garlic and herbs', 'n...             11
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...              8

# %% [markdown]
# ## Lower Case

# %%
def lowercase(text):
    text = text.lower()
    return text

new_df['ingredients_lower'] = new_df_droppedcols['ingredients'].apply(lowercase)

new_df.head()
# Out:
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                   all in the kitchen  chili  112140      130
# 3                          alouette  potatoes   59389       45
# 4          amish  tomato ketchup  for canning   44061      190
#
#    contributor_id   submitted  \
# 0           47892  2005-09-16
# 1           26278  2002-06-17
# 2          196586  2005-02-25
# 3           68585  2003-04-14
# 4           41706  2002-10-25
#
#                                                 tags  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...
# 1  ['30-minutes-or-less', 'time-to-make', 'course...
# 2  ['time-to-make', 'course', 'preparation', 'mai...
# 3  ['60-minutes-or-less', 'time-to-make', 'course...
# 4  ['weeknight', 'time-to-make', 'course', 'main-...
#
#                                     nutrition  n_steps  \
# 0       [51.5, 0.0, 13.0, 0.0, 2.0, 0.0, 4.0]       11
# 1   [173.4, 18.0, 0.0, 17.0, 22.0, 35.0, 1.0]        9
# 2  [269.8, 22.0, 32.0, 48.0, 39.0, 27.0, 5.0]        6
# 3   [368.1, 17.0, 10.0, 2.0, 14.0, 8.0, 20.0]       11
# 4   [352.9, 1.0, 337.0, 23.0, 3.0, 0.0, 28.0]        5
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['brown ground beef in large pot', 'add choppe...
# 3  ['place potatoes in a large pot of lightly sal...
# 4  ['mix all ingredients& boil for 2 1 / 2 hours ...
#
#                                          description  \
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...
# 2  this modified version of 'mom's' chili was a h...
# 3  this is a super easy, great tasting, make ahea...
# 4  my dh's amish mother raised him on this recipe...
#
#                                          ingredients  n_ingredients  \
# 0  ['winter squash', 'mexican seasoning', 'mixed ...              7
# 1  ['prepared pizza crust', 'sausage patty', 'egg...              6
# 2  ['ground beef', 'yellow onions', 'diced tomato...             13
# 3  ['spreadable cheese with garlic and herbs', 'n...             11
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...              8
#
#                                    ingredients_lower  \
# 0  ['winter squash', 'mexican seasoning', 'mixed ...
# 1  ['prepared pizza crust', 'sausage patty', 'egg...
# 2  ['ground beef', 'yellow onions', 'diced tomato...
# 3  ['spreadable cheese with garlic and herbs', 'n...
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...
#
#                                   ingredients_numout  \
# 0  ['winter squash', 'mexican seasoning', 'mixed ...
# 1  ['prepared pizza crust', 'sausage patty', 'egg...
# 2  ['ground beef', 'yellow onions', 'diced tomato...
# 3  ['spreadable cheese with garlic and herbs', 'n...
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...
#
#                                 ingredients_spaceout
# 0  ['winter squash', 'mexican seasoning', 'mixed ...
# 1  ['prepared pizza crust', 'sausage patty', 'egg...
# 2  ['ground beef', 'yellow onions', 'diced tomato...
# 3  ['spreadable cheese with garlic and herbs', 'n...
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...

# %% [markdown]
# ## Remove numbers

# %%
def remove_num(text):
    text = ''.join(char for char in text if not char.isdigit())
    return text

new_df['ingredients_numout'] = new_df['ingredients_lower'].apply(remove_num)

new_df.head()
# Out:
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                   all in the kitchen  chili  112140      130
# 3                          alouette  potatoes   59389       45
# 4          amish  tomato ketchup  for canning   44061      190
#
#    contributor_id   submitted  \
# 0           47892  2005-09-16
# 1           26278  2002-06-17
# 2          196586  2005-02-25
# 3           68585  2003-04-14
# 4           41706  2002-10-25
#
#                                                 tags  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...
# 1  ['30-minutes-or-less', 'time-to-make', 'course...
# 2  ['time-to-make', 'course', 'preparation', 'mai...
# 3  ['60-minutes-or-less', 'time-to-make', 'course...
# 4  ['weeknight', 'time-to-make', 'course', 'main-...
#
#                                     nutrition  n_steps  \
# 0       [51.5, 0.0, 13.0, 0.0, 2.0, 0.0, 4.0]       11
# 1   [173.4, 18.0, 0.0, 17.0, 22.0, 35.0, 1.0]        9
# 2  [269.8, 22.0, 32.0, 48.0, 39.0, 27.0, 5.0]        6
# 3   [368.1, 17.0, 10.0, 2.0, 14.0, 8.0, 20.0]       11
# 4   [352.9, 1.0, 337.0, 23.0, 3.0, 0.0, 28.0]        5
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['brown ground beef in large pot', 'add choppe...
# 3  ['place potatoes in a large pot of lightly sal...
# 4  ['mix all ingredients& boil for 2 1 / 2 hours ...
#
#                                          description  \
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...
# 2  this modified version of 'mom's' chili was a h...
# 3  this is a super easy, great tasting, make ahea...
# 4  my dh's amish mother raised him on this recipe...
#
#                                          ingredients  n_ingredients  \
# 0  ['winter squash', 'mexican seasoning', 'mixed ...              7
# 1  ['prepared pizza crust', 'sausage patty', 'egg...              6
# 2  ['ground beef', 'yellow onions', 'diced tomato...             13
# 3  ['spreadable cheese with garlic and herbs', 'n...             11
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...              8
#
#                                    ingredients_lower  \
# 0  ['winter squash', 'mexican seasoning', 'mixed ...
# 1  ['prepared pizza crust', 'sausage patty', 'egg...
# 2  ['ground beef', 'yellow onions', 'diced tomato...
# 3  ['spreadable cheese with garlic and herbs', 'n...
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...
#
#                                   ingredients_numout  \
# 0  ['winter squash', 'mexican seasoning', 'mixed ...
# 1  ['prepared pizza crust', 'sausage patty', 'egg...
# 2  ['ground beef', 'yellow onions', 'diced tomato...
# 3  ['spreadable cheese with garlic and herbs', 'n...
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...
#
#                                 ingredients_spaceout
# 0  ['winter squash', 'mexican seasoning', 'mixed ...
# 1  ['prepared pizza crust', 'sausage patty', 'egg...
# 2  ['ground beef', 'yellow onions', 'diced tomato...
# 3  ['spreadable cheese with garlic and herbs', 'n...
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...

# %% [markdown]
# ## Remove spaces

# %%
def remove_spaces(text):
    text = text.strip()
    return text

new_df['ingredients_spaceout'] = new_df['ingredients_numout'].apply(remove_spaces)

new_df.head()
# Out:
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                   all in the kitchen  chili  112140      130
# 3                          alouette  potatoes   59389       45
# 4          amish  tomato ketchup  for canning   44061      190
#
#    contributor_id   submitted  \
# 0           47892  2005-09-16
# 1           26278  2002-06-17
# 2          196586  2005-02-25
# 3           68585  2003-04-14
# 4           41706  2002-10-25
#
#                                                 tags  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...
# 1  ['30-minutes-or-less', 'time-to-make', 'course...
# 2  ['time-to-make', 'course', 'preparation', 'mai...
# 3  ['60-minutes-or-less', 'time-to-make', 'course...
# 4  ['weeknight', 'time-to-make', 'course', 'main-...
#
#                                     nutrition  n_steps  \
# 0       [51.5, 0.0, 13.0, 0.0, 2.0, 0.0, 4.0]       11
# 1   [173.4, 18.0, 0.0, 17.0, 22.0, 35.0, 1.0]        9
# 2  [269.8, 22.0, 32.0, 48.0, 39.0, 27.0, 5.0]        6
# 3   [368.1, 17.0, 10.0, 2.0, 14.0, 8.0, 20.0]       11
# 4   [352.9, 1.0, 337.0, 23.0, 3.0, 0.0, 28.0]        5
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['brown ground beef in large pot', 'add choppe...
# 3  ['place potatoes in a large pot of lightly sal...
# 4  ['mix all ingredients& boil for 2 1 / 2 hours ...
#
#                                          description  \
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...
# 2  this modified version of 'mom's' chili was a h...
# 3  this is a super easy, great tasting, make ahea...
# 4  my dh's amish mother raised him on this recipe...
#
#                                          ingredients  n_ingredients  \
# 0  ['winter squash', 'mexican seasoning', 'mixed ...              7
# 1  ['prepared pizza crust', 'sausage patty', 'egg...              6
# 2  ['ground beef', 'yellow onions', 'diced tomato...             13
# 3  ['spreadable cheese with garlic and herbs', 'n...             11
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...              8
#
#                                    ingredients_lower  \
# 0  ['winter squash', 'mexican seasoning', 'mixed ...
# 1  ['prepared pizza crust', 'sausage patty', 'egg...
# 2  ['ground beef', 'yellow onions', 'diced tomato...
# 3  ['spreadable cheese with garlic and herbs', 'n...
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...
#
#                                   ingredients_numout  \
# 0  ['winter squash', 'mexican seasoning', 'mixed ...
# 1  ['prepared pizza crust', 'sausage patty', 'egg...
# 2  ['ground beef', 'yellow onions', 'diced tomato...
# 3  ['spreadable cheese with garlic and herbs', 'n...
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...
#
#                                 ingredients_spaceout
# 0  ['winter squash', 'mexican seasoning', 'mixed ...
# 1  ['prepared pizza crust', 'sausage patty', 'egg...
# 2  ['ground beef', 'yellow onions', 'diced tomato...
# 3  ['spreadable cheese with garlic and herbs', 'n...
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...

# %% [markdown]
# ## Remove Stopwords

# %%
type(new_df['ingredients_spaceout'][0])
# Out:
# str

# %%
# delete this box: test
test_ing = "['salt', 'oil', 'beans ', ' chilis ', ' beans']"

# %%
test_rem = remove_stopwords(test_ing)
test_rem
# Out:
# "[ 'salt ' , 'oil ' , 'beans ' , ' chilis ' , ' beans ' ]"

# %%
test_rem.strip('[]').split(',')
# Out:
# [" 'salt ' ", " 'oil ' ", " 'beans ' ", " ' chilis ' ", " ' beans ' "]

# %%
# new stopwords in newStopWords variable to be edited

stopwords = nltk.corpus.stopwords.words('english')
newStopWords = ['salt', 'water', 'olive oil', 'vegetable oil', 'pepper', 'flour']
stopwords.extend(newStopWords)

def remove_stopwords(text):
    tokens = nltk.word_tokenize(text)
    new_text = [word for word in tokens if word.lower() not in stopwords]
    return ' '.join(new_text)
    

new_df['ingredients'] = new_df['ingredients_spaceout'].apply(remove_stopwords)
new_df.head()
# Out:
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                   all in the kitchen  chili  112140      130
# 3                          alouette  potatoes   59389       45
# 4          amish  tomato ketchup  for canning   44061      190
#
#    contributor_id   submitted  \
# 0           47892  2005-09-16
# 1           26278  2002-06-17
# 2          196586  2005-02-25
# 3           68585  2003-04-14
# 4           41706  2002-10-25
#
#                                                 tags  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...
# 1  ['30-minutes-or-less', 'time-to-make', 'course...
# 2  ['time-to-make', 'course', 'preparation', 'mai...
# 3  ['60-minutes-or-less', 'time-to-make', 'course...
# 4  ['weeknight', 'time-to-make', 'course', 'main-...
#
#                                     nutrition  n_steps  \
# 0       [51.5, 0.0, 13.0, 0.0, 2.0, 0.0, 4.0]       11
# 1   [173.4, 18.0, 0.0, 17.0, 22.0, 35.0, 1.0]        9
# 2  [269.8, 22.0, 32.0, 48.0, 39.0, 27.0, 5.0]        6
# 3   [368.1, 17.0, 10.0, 2.0, 14.0, 8.0, 20.0]       11
# 4   [352.9, 1.0, 337.0, 23.0, 3.0, 0.0, 28.0]        5
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['brown ground beef in large pot', 'add choppe...
# 3  ['place potatoes in a large pot of lightly sal...
# 4  ['mix all ingredients& boil for 2 1 / 2 hours ...
#
#                                          description  \
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...
# 2  this modified version of 'mom's' chili was a h...
# 3  this is a super easy, great tasting, make ahea...
# 4  my dh's amish mother raised him on this recipe...
#
#                                          ingredients  n_ingredients  \
# 0  [ 'winter squash ' , 'mexican seasoning ' , 'm...              7
# 1  [ 'prepared pizza crust ' , 'sausage patty ' ,...              6
# 2  [ 'ground beef ' , 'yellow onions ' , 'diced t...             13
# 3  [ 'spreadable cheese garlic herbs ' , 'new pot...             11
# 4  [ 'tomato juice ' , 'apple cider vinegar ' , '...              8
#
#                                    ingredients_lower  \
# 0  ['winter squash', 'mexican seasoning', 'mixed ...
# 1  ['prepared pizza crust', 'sausage patty', 'egg...
# 2  ['ground beef', 'yellow onions', 'diced tomato...
# 3  ['spreadable cheese with garlic and herbs', 'n...
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...
#
#                                   ingredients_numout  \
# 0  ['winter squash', 'mexican seasoning', 'mixed ...
# 1  ['prepared pizza crust', 'sausage patty', 'egg...
# 2  ['ground beef', 'yellow onions', 'diced tomato...
# 3  ['spreadable cheese with garlic and herbs', 'n...
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...
#
#                                 ingredients_spaceout  \
# 0  ['winter squash', 'mexican seasoning', 'mixed ...
# 1  ['prepared pizza crust', 'sausage patty', 'egg...
# 2  ['ground beef', 'yellow onions', 'diced tomato...
# 3  ['spreadable cheese with garlic and herbs', 'n...
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...
#
#                                     ingredients_list  \
# 0  [ 'winter squash ' ,  'mexican seasoning ' ,  ...
# 1  [ 'prepared pizza crust ' ,  'sausage patty ' ...
# 2  [ 'ground beef ' ,  'yellow onions ' ,  'diced...
# 3  [ 'spreadable cheese garlic herbs ' ,  'new po...
# 4  [ 'tomato juice ' ,  'apple cider vinegar ' , ...
#
#                               clean_ingredients_list  \
# 0  [ winter squash  ,  mexican seasoning  ,  mixe...
# 1  [ prepared pizza crust  ,  sausage patty  ,  e...
# 2  [ ground beef  ,  yellow onions  ,  diced toma...
# 3  [ spreadable cheese garlic herbs  ,  new potat...
# 4  [ tomato juice  ,  apple cider vinegar  ,  sug...
#
#                                clean_ingredients_set
# 0  { butter  ,  salt  ,  mixed spice  ,  winter s...
# 1  { prepared pizza crust  ,  salt  ,  cheese  , ...
# 2  { tomato soup  ,  chili powder  ,  yellow onio...
# 3  { parsley  ,  red bell  ,  shallots  ,  new po...
# 4  { dry mustard  ,  salt  ,  pepper  ,  clove oi...

# %%
teststop = remove_stopwords(test_ing)
teststop
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[181], line 1
# ----> 1 teststop = remove_stopwords(test_ing)
#       2 teststop
#
# Cell In[121], line 8, in remove_stopwords(text)
#       7 def remove_stopwords(text):
# ----> 8     tokens = nltk.word_tokenize(text)
#       9     new_text = [word for word in tokens if word.lower() not in stopwords]
#      10     return ' '.join(new_text)
#
# File ~/.pyenv/versions/3.10.6/envs/potluck_project/lib/python3.10/site-packages/nltk/tokenize/__init__.py:129, in word_tokenize(text, language, preserve_line)
#     114 def word_tokenize(text, language="english", preserve_line=False):
#     115     """
#     116     Return a tokenized copy of *text*,
#     117     using NLTK's recommended word tokenizer
#    (...)
#     127     :type preserve_line: bool
#     128     """
# --> 129     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     130     return [
#     131         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#     132     ]
#
# File ~/.pyenv/versions/3.10.6/envs/potluck_project/lib/python3.10/site-packages/nltk/tokenize/__init__.py:107, in sent_tokenize(text, language)
#      97 """
#      98 Return a sentence-tokenized copy of *text*,
#      99 using NLTK's recommended sentence tokenizer
#    (...)
#     104 :param language: the model name in the Punkt corpus
#     105 """
#     106 tokenizer = load(f"tokenizers/punkt/{language}.pickle")
# --> 107 return tokenizer.tokenize(text)
#
# File ~/.pyenv/versions/3.10.6/envs/potluck_project/lib/python3.10/site-packages/nltk/tokenize/punkt.py:1281, in PunktSentenceTokenizer.tokenize(self, text, realign_boundaries)
#    1277 def tokenize(self, text: str, realign_boundaries: bool = True) -> List[str]:
#    1278     """
#    1279     Given a text, returns a list of the sentences in that text.
#    1280     """
# -> 1281     return list(self.sentences_from_text(text, realign_boundaries))
#
# File ~/.pyenv/versions/3.10.6/envs/potluck_project/lib/python3.10/site-packages/nltk/tokenize/punkt.py:1341, in PunktSentenceTokenizer.sentences_from_text(self, text, realign_boundaries)
#    1332 def sentences_from_text(
#    1333     self, text: str, realign_boundaries: bool = True
#    1334 ) -> List[str]:
#    1335     """
#    1336     Given a text, generates the sentences in that text by only
#    1337     testing candidate sentence breaks. If realign_boundaries is
#    1338     True, includes in the sentence closing punctuation that
#    1339     follows the period.
#    1340     """
# -> 1341     return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#
# File ~/.pyenv/versions/3.10.6/envs/potluck_project/lib/python3.10/site-packages/nltk/tokenize/punkt.py:1341, in <listcomp>(.0)
#    1332 def sentences_from_text(
#    1333     self, text: str, realign_boundaries: bool = True
#    1334 ) -> List[str]:
#    1335     """
#    1336     Given a text, generates the sentences in that text by only
#    1337     testing candidate sentence breaks. If realign_boundaries is
#    1338     True, includes in the sentence closing punctuation that
#    1339     follows the period.
#    1340     """
# -> 1341     return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#
# File ~/.pyenv/versions/3.10.6/envs/potluck_project/lib/python3.10/site-packages/nltk/tokenize/punkt.py:1329, in PunktSentenceTokenizer.span_tokenize(self, text, realign_boundaries)
#    1327 if realign_boundaries:
#    1328     slices = self._realign_boundaries(text, slices)
# -> 1329 for sentence in slices:
#    1330     yield (sentence.start, sentence.stop)
#
# File ~/.pyenv/versions/3.10.6/envs/potluck_project/lib/python3.10/site-packages/nltk/tokenize/punkt.py:1459, in PunktSentenceTokenizer._realign_boundaries(self, text, slices)
#    1446 """
#    1447 Attempts to realign punctuation that falls after the period but
#    1448 should otherwise be included in the same sentence.
#    (...)
#    1456     ["(Sent1.)", "Sent2."].
#    1457 """
#    1458 realign = 0
# -> 1459 for sentence1, sentence2 in _pair_iter(slices):
#    1460     sentence1 = slice(sentence1.start + realign, sentence1.stop)
#    1461     if not sentence2:
#
# File ~/.pyenv/versions/3.10.6/envs/potluck_project/lib/python3.10/site-packages/nltk/tokenize/punkt.py:321, in _pair_iter(iterator)
#     319 iterator = iter(iterator)
#     320 try:
# --> 321     prev = next(iterator)
#     322 except StopIteration:
#     323     return
#
# File ~/.pyenv/versions/3.10.6/envs/potluck_project/lib/python3.10/site-packages/nltk/tokenize/punkt.py:1431, in PunktSentenceTokenizer._slices_from_text(self, text)
#    1429 def _slices_from_text(self, text: str) -> Iterator[slice]:
#    1430     last_break = 0
# -> 1431     for match, context in self._match_potential_end_contexts(text):
#    1432         if self.text_contains_sentbreak(context):
#    1433             yield slice(last_break, match.end())
#
# File ~/.pyenv/versions/3.10.6/envs/potluck_project/lib/python3.10/site-packages/nltk/tokenize/punkt.py:1395, in PunktSentenceTokenizer._match_potential_end_contexts(self, text)
#    1393 previous_slice = slice(0, 0)
#    1394 previous_match = None
# -> 1395 for match in self._lang_vars.period_context_re().finditer(text):
#    1396
#    1397     # Get the slice of the previous word
#    1398     before_text = text[previous_slice.stop : match.start()]
#    1399     index_after_last_space = self._get_last_whitespace_index(before_text)
#
# TypeError: expected string or bytes-like object

# %% [markdown]
# ## Create list column from ingredients string column

# %%
new_df['ingredients_list'] = new_df['ingredients'].apply(lambda x: x.strip('[]').split(','))

# %%
new_df.head()
# Out:
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                   all in the kitchen  chili  112140      130
# 3                          alouette  potatoes   59389       45
# 4          amish  tomato ketchup  for canning   44061      190
#
#    contributor_id   submitted  \
# 0           47892  2005-09-16
# 1           26278  2002-06-17
# 2          196586  2005-02-25
# 3           68585  2003-04-14
# 4           41706  2002-10-25
#
#                                                 tags  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...
# 1  ['30-minutes-or-less', 'time-to-make', 'course...
# 2  ['time-to-make', 'course', 'preparation', 'mai...
# 3  ['60-minutes-or-less', 'time-to-make', 'course...
# 4  ['weeknight', 'time-to-make', 'course', 'main-...
#
#                                     nutrition  n_steps  \
# 0       [51.5, 0.0, 13.0, 0.0, 2.0, 0.0, 4.0]       11
# 1   [173.4, 18.0, 0.0, 17.0, 22.0, 35.0, 1.0]        9
# 2  [269.8, 22.0, 32.0, 48.0, 39.0, 27.0, 5.0]        6
# 3   [368.1, 17.0, 10.0, 2.0, 14.0, 8.0, 20.0]       11
# 4   [352.9, 1.0, 337.0, 23.0, 3.0, 0.0, 28.0]        5
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['brown ground beef in large pot', 'add choppe...
# 3  ['place potatoes in a large pot of lightly sal...
# 4  ['mix all ingredients& boil for 2 1 / 2 hours ...
#
#                                          description  \
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...
# 2  this modified version of 'mom's' chili was a h...
# 3  this is a super easy, great tasting, make ahea...
# 4  my dh's amish mother raised him on this recipe...
#
#                                          ingredients  n_ingredients  \
# 0  [ 'winter squash ' , 'mexican seasoning ' , 'm...              7
# 1  [ 'prepared pizza crust ' , 'sausage patty ' ,...              6
# 2  [ 'ground beef ' , 'yellow onions ' , 'diced t...             13
# 3  [ 'spreadable cheese garlic herbs ' , 'new pot...             11
# 4  [ 'tomato juice ' , 'apple cider vinegar ' , '...              8
#
#                                    ingredients_lower  \
# 0  ['winter squash', 'mexican seasoning', 'mixed ...
# 1  ['prepared pizza crust', 'sausage patty', 'egg...
# 2  ['ground beef', 'yellow onions', 'diced tomato...
# 3  ['spreadable cheese with garlic and herbs', 'n...
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...
#
#                                   ingredients_numout  \
# 0  ['winter squash', 'mexican seasoning', 'mixed ...
# 1  ['prepared pizza crust', 'sausage patty', 'egg...
# 2  ['ground beef', 'yellow onions', 'diced tomato...
# 3  ['spreadable cheese with garlic and herbs', 'n...
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...
#
#                                 ingredients_spaceout  \
# 0  ['winter squash', 'mexican seasoning', 'mixed ...
# 1  ['prepared pizza crust', 'sausage patty', 'egg...
# 2  ['ground beef', 'yellow onions', 'diced tomato...
# 3  ['spreadable cheese with garlic and herbs', 'n...
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...
#
#                                     ingredients_list
# 0  [ 'winter squash ' ,  'mexican seasoning ' ,  ...
# 1  [ 'prepared pizza crust ' ,  'sausage patty ' ...
# 2  [ 'ground beef ' ,  'yellow onions ' ,  'diced...
# 3  [ 'spreadable cheese garlic herbs ' ,  'new po...
# 4  [ 'tomato juice ' ,  'apple cider vinegar ' , ...

# %%
type(new_df['ingredients_list'][0])
# Out:
# list

# %% [markdown]
# ## Remove punctuation

# %%
def remove_punct_list(text):
    cleaned_text = []
    for word in text:
        for punctuation in string.punctuation:
            word = word.replace(punctuation, '')
        cleaned_text.append(word)
    return cleaned_text

# %%
new_df['clean_ingredients_list'] = new_df['ingredients_list'].apply(remove_punct_list)    

new_df.head()
# Out:
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                   all in the kitchen  chili  112140      130
# 3                          alouette  potatoes   59389       45
# 4          amish  tomato ketchup  for canning   44061      190
#
#    contributor_id   submitted  \
# 0           47892  2005-09-16
# 1           26278  2002-06-17
# 2          196586  2005-02-25
# 3           68585  2003-04-14
# 4           41706  2002-10-25
#
#                                                 tags  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...
# 1  ['30-minutes-or-less', 'time-to-make', 'course...
# 2  ['time-to-make', 'course', 'preparation', 'mai...
# 3  ['60-minutes-or-less', 'time-to-make', 'course...
# 4  ['weeknight', 'time-to-make', 'course', 'main-...
#
#                                     nutrition  n_steps  \
# 0       [51.5, 0.0, 13.0, 0.0, 2.0, 0.0, 4.0]       11
# 1   [173.4, 18.0, 0.0, 17.0, 22.0, 35.0, 1.0]        9
# 2  [269.8, 22.0, 32.0, 48.0, 39.0, 27.0, 5.0]        6
# 3   [368.1, 17.0, 10.0, 2.0, 14.0, 8.0, 20.0]       11
# 4   [352.9, 1.0, 337.0, 23.0, 3.0, 0.0, 28.0]        5
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['brown ground beef in large pot', 'add choppe...
# 3  ['place potatoes in a large pot of lightly sal...
# 4  ['mix all ingredients& boil for 2 1 / 2 hours ...
#
#                                          description  \
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...
# 2  this modified version of 'mom's' chili was a h...
# 3  this is a super easy, great tasting, make ahea...
# 4  my dh's amish mother raised him on this recipe...
#
#                                          ingredients  n_ingredients  \
# 0  [ 'winter squash ' , 'mexican seasoning ' , 'm...              7
# 1  [ 'prepared pizza crust ' , 'sausage patty ' ,...              6
# 2  [ 'ground beef ' , 'yellow onions ' , 'diced t...             13
# 3  [ 'spreadable cheese garlic herbs ' , 'new pot...             11
# 4  [ 'tomato juice ' , 'apple cider vinegar ' , '...              8
#
#                                    ingredients_lower  \
# 0  ['winter squash', 'mexican seasoning', 'mixed ...
# 1  ['prepared pizza crust', 'sausage patty', 'egg...
# 2  ['ground beef', 'yellow onions', 'diced tomato...
# 3  ['spreadable cheese with garlic and herbs', 'n...
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...
#
#                                   ingredients_numout  \
# 0  ['winter squash', 'mexican seasoning', 'mixed ...
# 1  ['prepared pizza crust', 'sausage patty', 'egg...
# 2  ['ground beef', 'yellow onions', 'diced tomato...
# 3  ['spreadable cheese with garlic and herbs', 'n...
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...
#
#                                 ingredients_spaceout  \
# 0  ['winter squash', 'mexican seasoning', 'mixed ...
# 1  ['prepared pizza crust', 'sausage patty', 'egg...
# 2  ['ground beef', 'yellow onions', 'diced tomato...
# 3  ['spreadable cheese with garlic and herbs', 'n...
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...
#
#                                     ingredients_list  \
# 0  [ 'winter squash ' ,  'mexican seasoning ' ,  ...
# 1  [ 'prepared pizza crust ' ,  'sausage patty ' ...
# 2  [ 'ground beef ' ,  'yellow onions ' ,  'diced...
# 3  [ 'spreadable cheese garlic herbs ' ,  'new po...
# 4  [ 'tomato juice ' ,  'apple cider vinegar ' , ...
#
#                               clean_ingredients_list
# 0  [ winter squash  ,  mexican seasoning  ,  mixe...
# 1  [ prepared pizza crust  ,  sausage patty  ,  e...
# 2  [ ground beef  ,  yellow onions  ,  diced toma...
# 3  [ spreadable cheese garlic herbs  ,  new potat...
# 4  [ tomato juice  ,  apple cider vinegar  ,  sug...

# %%
type(new_df['clean_ingredients_list'][0])
# Out:
# list

# %%
# temporary check
new_df['clean_ingredients_list'][0]
# Out:
# [' winter squash  ',
#  ' mexican seasoning  ',
#  ' mixed spice  ',
#  ' honey  ',
#  ' butter  ',
#  ' olive oil  ',
#  ' salt  ']

# %%
new_df['clean_ingredients_set'] = new_df['clean_ingredients_list'].apply(set)

new_df.head(5)
# Out:
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                   all in the kitchen  chili  112140      130
# 3                          alouette  potatoes   59389       45
# 4          amish  tomato ketchup  for canning   44061      190
#
#    contributor_id   submitted  \
# 0           47892  2005-09-16
# 1           26278  2002-06-17
# 2          196586  2005-02-25
# 3           68585  2003-04-14
# 4           41706  2002-10-25
#
#                                                 tags  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...
# 1  ['30-minutes-or-less', 'time-to-make', 'course...
# 2  ['time-to-make', 'course', 'preparation', 'mai...
# 3  ['60-minutes-or-less', 'time-to-make', 'course...
# 4  ['weeknight', 'time-to-make', 'course', 'main-...
#
#                                     nutrition  n_steps  \
# 0       [51.5, 0.0, 13.0, 0.0, 2.0, 0.0, 4.0]       11
# 1   [173.4, 18.0, 0.0, 17.0, 22.0, 35.0, 1.0]        9
# 2  [269.8, 22.0, 32.0, 48.0, 39.0, 27.0, 5.0]        6
# 3   [368.1, 17.0, 10.0, 2.0, 14.0, 8.0, 20.0]       11
# 4   [352.9, 1.0, 337.0, 23.0, 3.0, 0.0, 28.0]        5
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['brown ground beef in large pot', 'add choppe...
# 3  ['place potatoes in a large pot of lightly sal...
# 4  ['mix all ingredients& boil for 2 1 / 2 hours ...
#
#                                          description  \
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...
# 2  this modified version of 'mom's' chili was a h...
# 3  this is a super easy, great tasting, make ahea...
# 4  my dh's amish mother raised him on this recipe...
#
#                                          ingredients  n_ingredients  \
# 0  [ 'winter squash ' , 'mexican seasoning ' , 'm...              7
# 1  [ 'prepared pizza crust ' , 'sausage patty ' ,...              6
# 2  [ 'ground beef ' , 'yellow onions ' , 'diced t...             13
# 3  [ 'spreadable cheese garlic herbs ' , 'new pot...             11
# 4  [ 'tomato juice ' , 'apple cider vinegar ' , '...              8
#
#                                    ingredients_lower  \
# 0  ['winter squash', 'mexican seasoning', 'mixed ...
# 1  ['prepared pizza crust', 'sausage patty', 'egg...
# 2  ['ground beef', 'yellow onions', 'diced tomato...
# 3  ['spreadable cheese with garlic and herbs', 'n...
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...
#
#                                   ingredients_numout  \
# 0  ['winter squash', 'mexican seasoning', 'mixed ...
# 1  ['prepared pizza crust', 'sausage patty', 'egg...
# 2  ['ground beef', 'yellow onions', 'diced tomato...
# 3  ['spreadable cheese with garlic and herbs', 'n...
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...
#
#                                 ingredients_spaceout  \
# 0  ['winter squash', 'mexican seasoning', 'mixed ...
# 1  ['prepared pizza crust', 'sausage patty', 'egg...
# 2  ['ground beef', 'yellow onions', 'diced tomato...
# 3  ['spreadable cheese with garlic and herbs', 'n...
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...
#
#                                     ingredients_list  \
# 0  [ 'winter squash ' ,  'mexican seasoning ' ,  ...
# 1  [ 'prepared pizza crust ' ,  'sausage patty ' ...
# 2  [ 'ground beef ' ,  'yellow onions ' ,  'diced...
# 3  [ 'spreadable cheese garlic herbs ' ,  'new po...
# 4  [ 'tomato juice ' ,  'apple cider vinegar ' , ...
#
#                               clean_ingredients_list  \
# 0  [ winter squash  ,  mexican seasoning  ,  mixe...
# 1  [ prepared pizza crust  ,  sausage patty  ,  e...
# 2  [ ground beef  ,  yellow onions  ,  diced toma...
# 3  [ spreadable cheese garlic herbs  ,  new potat...
# 4  [ tomato juice  ,  apple cider vinegar  ,  sug...
#
#                                clean_ingredients_set
# 0  { butter  ,  salt  ,  mixed spice  ,  winter s...
# 1  { prepared pizza crust  ,  salt  ,  cheese  , ...
# 2  { tomato soup  ,  chili powder  ,  yellow onio...
# 3  { parsley  ,  red bell  ,  shallots  ,  new po...
# 4  { dry mustard  ,  salt  ,  pepper  ,  clove oi...

# %%
preprocessed_df = new_df[['name', 'steps', 'clean_ingredients_set']]

preprocessed_df.head()
# Out:
#                                          name  \
# 0  arriba   baked winter squash mexican style
# 1            a bit different  breakfast pizza
# 2                   all in the kitchen  chili
# 3                          alouette  potatoes
# 4          amish  tomato ketchup  for canning
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['brown ground beef in large pot', 'add choppe...
# 3  ['place potatoes in a large pot of lightly sal...
# 4  ['mix all ingredients& boil for 2 1 / 2 hours ...
#
#                                clean_ingredients_set
# 0  { butter  ,  salt  ,  mixed spice  ,  winter s...
# 1  { prepared pizza crust  ,  salt  ,  cheese  , ...
# 2  { tomato soup  ,  chili powder  ,  yellow onio...
# 3  { parsley  ,  red bell  ,  shallots  ,  new po...
# 4  { dry mustard  ,  salt  ,  pepper  ,  clove oi...

# %%
preprocessed_df.head()
# Out:
#                                          name  \
# 0  arriba   baked winter squash mexican style
# 1            a bit different  breakfast pizza
# 2                   all in the kitchen  chili
# 3                          alouette  potatoes
# 4          amish  tomato ketchup  for canning
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['brown ground beef in large pot', 'add choppe...
# 3  ['place potatoes in a large pot of lightly sal...
# 4  ['mix all ingredients& boil for 2 1 / 2 hours ...
#
#                                clean_ingredients_set
# 0  { butter  ,  salt  ,  mixed spice  ,  winter s...
# 1  { prepared pizza crust  ,  salt  ,  cheese  , ...
# 2  { tomato soup  ,  chili powder  ,  yellow onio...
# 3  { parsley  ,  red bell  ,  shallots  ,  new po...
# 4  { dry mustard  ,  salt  ,  pepper  ,  clove oi...

# %%
# simulation of user search - based on df
input_list1 = list(preprocessed_df['clean_ingredients_set'][0])
print(input_list1)
# Out:
# [' butter  ', ' salt  ', ' mixed spice  ', ' winter squash  ', ' mexican seasoning  ', ' olive oil  ', ' honey  ']

# %%
# simulation of user search - made-up ingredients
input_list2 = ['bUtter', '2 tomatoes', 'beans ']
print(input_list2)
# Out:
# ['bUtter', '2 tomatoes', 'beans ']

# %%
# test 1 preproc func - with my_ing.strip..split()
def preproc1(feature):
    
    
    # lowercase
    my_ing = [ingr.lower() for ingr in feature]
    print(f'{my_ing}  lowercased. Type is {type(my_ing)}')
    # remove numbers
    my_ing = [remove_num(ingr) for ingr in my_ing]
    print(f'{my_ing} removed nums. Type is {type(my_ing)}')
    # remove stopwds
    my_ing = remove_stopwords(' '.join(my_ing)).split()
    print(f'{my_ing} removed stopwds. Type is {type(my_ing)}')
    
    #string to list (for df)- alternatively try my_ing = list(my_ing)
    my_ing = my_ing.strip('[]').split(',')
    #my_ing = list(my_ing)
    print(f'{my_ing} changed type to list. Type is {type(my_ing)}')
    
    #remove punctuation
    my_ing = remove_punct_list(my_ing)
    print(f'{my_ing} removed punct. Type is {type(my_ing)}')
    
    return my_ing

# %%
# test 2 preproc func - with list(my_ing)
def preproc2(feature):
    
    
    # lowercase
    my_ing = [ingr.lower() for ingr in feature]
    print(f'{my_ing}  lowercased. Type is {type(my_ing)}')
    # remove numbers
    my_ing = [remove_num(ingr) for ingr in my_ing]
    print(f'{my_ing} removed nums. Type is {type(my_ing)}')
    # remove stopwds
    my_ing = remove_stopwords(' '.join(my_ing)).split()
    print(f'{my_ing} removed stopwds. Type is {type(my_ing)}')
    
    #string to list (for df)- alternatively try my_ing = list(my_ing)
    #my_ing = my_ing.strip('[]').split(',')
    my_ing = list(my_ing)
    print(f'{my_ing} changed type to list. Type is {type(my_ing)}')
    
    #remove punctuation
    my_ing = remove_punct_list(my_ing)
    print(f'{my_ing} removed punct. Type is {type(my_ing)}')
    
    return my_ing

# %%
# test 3 preproc func - with list(my_ing) at start
def preproc3(feature):
    
    my_ing = list(feature)
    
    # lowercase
    my_ing = [ingr.lower() for ingr in my_ing]
    print(f'{my_ing}  lowercased. Type is {type(my_ing)}')
    # remove numbers
    my_ing = [remove_num(ingr) for ingr in my_ing]
    print(f'{my_ing} removed nums. Type is {type(my_ing)}')
    # remove stopwds
    my_ing = remove_stopwords(' '.join(my_ing)).split()
    print(f'{my_ing} removed stopwds. Type is {type(my_ing)}')
    
    #string to list (for df)- alternatively try my_ing = list(my_ing)
    #my_ing = my_ing.strip('[]').split(',')
    #my_ing = list(my_ing)
    print(f'{my_ing} changed type to list. Type is {type(my_ing)}')
    
    #remove punctuation
    my_ing = remove_punct_list(my_ing)
    print(f'{my_ing} removed punct. Type is {type(my_ing)}')
    
    return my_ing

# %%
# test preproc function

preproc(input_list1)
# Out:
# [' butter  ', ' salt  ', ' mixed spice  ', ' winter squash  ', ' mexican seasoning  ', ' olive oil  ', ' honey  ']  lowercased. Type is <class 'list'>
# [' butter  ', ' salt  ', ' mixed spice  ', ' winter squash  ', ' mexican seasoning  ', ' olive oil  ', ' honey  '] removed nums. Type is <class 'list'>
# ['butter', 'mixed', 'spice', 'winter', 'squash', 'mexican', 'seasoning', 'olive', 'oil', 'honey'] removed stopwds. Type is <class 'list'>
# ['butter', 'mixed', 'spice', 'winter', 'squash', 'mexican', 'seasoning', 'olive', 'oil', 'honey'] removed punct. Type is <class 'list'>
# ['butter',
#  'mixed',
#  'spice',
#  'winter',
#  'squash',
#  'mexican',
#  'seasoning',
#  'olive',
#  'oil',
#  'honey']

# %% [markdown]
# ## trial of creating df using preproc function

# %%
# check last version of df before preproc
new_df_droppedcols.head()
# Out:
#                                          name  \
# 0  arriba   baked winter squash mexican style
# 1            a bit different  breakfast pizza
# 2                   all in the kitchen  chili
# 3                          alouette  potatoes
# 4          amish  tomato ketchup  for canning
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['brown ground beef in large pot', 'add choppe...
# 3  ['place potatoes in a large pot of lightly sal...
# 4  ['mix all ingredients& boil for 2 1 / 2 hours ...
#
#                                          ingredients
# 0  ['winter squash', 'mexican seasoning', 'mixed ...
# 1  ['prepared pizza crust', 'sausage patty', 'egg...
# 2  ['ground beef', 'yellow onions', 'diced tomato...
# 3  ['spreadable cheese with garlic and herbs', 'n...
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...

# %%
# investigate ingredients feature
print(new_df_droppedcols['ingredients'][0])
# Out:
# ['winter squash', 'mexican seasoning', 'mixed spice', 'honey', 'butter', 'olive oil', 'salt']

# %%
testlist = list(new_df_droppedcols['ingredients'][0])

# %%
type(testlist)
# Out:
# list

# %%
def easy_search(user_input):
    # preproc
    my_ing = preproc(user_input)
        # search    
    return preprocessed_df[preprocessed_df['clean_ingredients_set'].apply(lambda x: x.issubset(my_ing))]

# %%
#first baseline attempt

def easy_search(user_input):
    # preproc
    # lowercase
    my_ing = [ingr.lower() for ingr in user_input]
    print(f'{my_ing}  lowercased')
    # remove numbers
    my_ing = [remove_num(ingr) for ingr in my_ing]
    print(f'{my_ing} removed nums')
    # remove stopwds
    my_ing = remove_stopwords(' '.join(my_ing)).split()
    print(f'{my_ing} removed stopwds')
    #remove punctuation
    my_ing = remove_punct_list(my_ing)
    print(f'{my_ing} removed punct')
    #convert to set
    my_ing = set(my_ing)
    print(f'{my_ing} converted to set')
    # search    
    return preprocessed_df[preprocessed_df['clean_ingredients_set'].apply(lambda x: x.issubset(my_ing))]

    #return preprocessed_df

# %%
easy_search(input_list)
# Out:
# [' butter  ', ' salt  ', ' mixed spice  ', ' winter squash  ', ' mexican seasoning  ', ' olive oil  ', ' honey  ']  lowercased
# [' butter  ', ' salt  ', ' mixed spice  ', ' winter squash  ', ' mexican seasoning  ', ' olive oil  ', ' honey  '] removed nums
# ['butter', 'mixed', 'spice', 'winter', 'squash', 'mexican', 'seasoning', 'olive', 'oil', 'honey'] removed stopwds
# ['butter', 'mixed', 'spice', 'winter', 'squash', 'mexican', 'seasoning', 'olive', 'oil', 'honey'] removed punct
# {'spice', 'mexican', 'oil', 'olive', 'seasoning', 'squash', 'honey', 'mixed', 'butter', 'winter'} converted to set
# Empty DataFrame
# Columns: [name, steps, clean_ingredients_set]
# Index: []
